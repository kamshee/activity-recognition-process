# %% [markdown]
# # Stroke Length of Stay vs Length of Data Collection
# - Data Visualization
# - Waiting on Length of Data Collection numbers

# %%
# import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# import re
import copy
# %matplotlib inline

# %% [markdown]
# # Real Data

# %%
# Length of Stay (LOS)
los = pd.read_csv('Documents/GitHub/LOS.csv')

# %%
len(los)
# Out:
# 33

# %%
los.describe()
# Out:
#               19
# count  33.000000
# mean   25.121212
# std     9.201758
# min     9.000000
# 25%    18.000000
# 50%    24.000000
# 75%    33.000000
# max    47.000000

# %% [markdown]
# # Plot univariate distributions
# - histogram with fitted kernel density estimate (KDE)

# %%
# x = np.random.normal(size=100)
sns.distplot(los);

# %%
# Histogram with rug plot (tick for every observation)
sns.distplot(los, kde=False, rug=True)

# %%
sns.distplot(los,
             hist_kws=dict(cumulative=True),
             kde_kws=dict(cumulative=True))
plt.title('LOS')
# plt.legend(loc='lower right')
plt.xlabel('Days')
plt.ylabel('Likelihood of occurrence')
plt.show()

# %% [markdown]
# # Histogram

# %%
# 1 histogram
plt.title('Histogram from LOS')
plt.xlabel('Days')
plt.hist(los, bins=10, normed=True, color='red', alpha=0.2)
# plt.hist(example.iloc[:,0], bins=30, normed=True, color='red', alpha=0.2)
# Display the plot
plt.show()
